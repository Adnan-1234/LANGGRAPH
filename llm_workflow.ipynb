# %%
from langchain_groq import ChatGroq
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv(dotenv_path='.env', override=True)
# Out:
# True

# %%
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.3-70b-versatile",  
    api_key=GROQ_API_KEY  
)

# %%
class Query(TypedDict):
    question: str
    answer:str

# %%
def Question(state: Query) -> Query:
    question=state['question']
    prompt=f"Answer the following question in pointwise format:{question}"
    answer=model.invoke(prompt).content
    state['answer']=answer
    return state

# %%
graph=StateGraph(Query)

# %%
graph.add_node('Question',Question)

# %%
graph.add_edge(START,'Question')
graph.add_edge('Question',END)

# %%
workflow = graph.compile()

# %%
initial_state={'question': 'What are the benefits of using LangGraph?'}
final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# Here are the benefits of using LangGraph:
#
# * **Improved language understanding**: LangGraph uses advanced AI and machine learning algorithms to analyze and understand language, providing accurate and insightful results.
# * **Enhanced text analysis**: LangGraph can analyze large amounts of text data, identifying patterns, relationships, and trends that may not be immediately apparent.
# * **Entity recognition and disambiguation**: LangGraph can identify and disambiguate entities in text, such as people, places, and organizations, allowing for more accurate and efficient analysis.
# * **Relationship mapping**: LangGraph can map relationships between entities, concepts, and ideas, providing a deeper understanding of the context and meaning of text.
# * **Knowledge graph construction**: LangGraph can construct knowledge graphs that represent the relationships between entities, concepts, and ideas, providing a visual and intuitive representation of complex data.
# * **Question answering and information retrieval**: LangGraph can be used to answer questions and retrieve information from large datasets, using natural language queries and search terms.
# * **Text summarization and generation**: LangGraph can summarize and generate text, using advanced language generation algorithms to create coherent and natural-sounding text.
# * **Sentiment analysis and opinion mining**: LangGraph can analyze text to determine sentiment and opinion, providing insights into public opinion and sentiment on various topics.
# * **Multi-language support**: LangGraph can analyze and understand text in multiple languages, making it a powerful tool for global communication and analysis.
# * **Scalability and flexibility**: LangGraph can be used with large and small datasets, and can be integrated with a variety of tools and platforms, making it a flexible and scalable solution for language analysis and understanding.

# %%
from
