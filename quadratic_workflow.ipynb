# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict,Literal

# %%
class QuadraticState(TypedDict):
    a: float
    b: float
    c: float
    equation: str
    discriminant: float
    result: str

# %%
def show_equation(state:QuadraticState) -> QuadraticState:
    a = state['a']
    b = state['b']
    c = state['c']
    state['equation'] = f"{a}x^2 + {b}x + {c} = 0"
    return {'equation': state['equation']}

# %%
def calculate_discriminant(state:QuadraticState) -> QuadraticState:
    a = state['a']
    b = state['b']
    c = state['c']
    state['discriminant'] = b**2 - 4*a*c
    return {'discriminant': state['discriminant']}

# %%
def real_roots(state:QuadraticState) -> QuadraticState:
    a = state['a']
    b = state['b']
    c = state['c']
    d = state['discriminant']
    root1 = (-b + d**0.5) / (2*a)
    root2 = (-b - d**0.5) / (2*a)
    state['result'] = f"Two real roots: {root1} and {root2}"
    return {'result': state['result']}

# %%
def repeated_roots(state:QuadraticState) -> QuadraticState:
    a = state['a']
    b = state['b']
    c = state['c']
    d = state['discriminant']
    root = -b / (2*a)
    state['result'] = f"One repeated root: {root}"
    return {'result': state['result']}

# %%
def no_real_roots(state:QuadraticState) -> QuadraticState:
    state['result'] = "No real roots"
    return {'result': state['result']}

# %%
def check_condition(state:QuadraticState) -> Literal['real_roots', 'repeated_roots', 'no_real_roots']:
    d = state['discriminant']
    if d > 0:
        return 'real_roots'
    elif d == 0:
        return 'repeated_roots'
    else:
        return 'no_real_roots'

# %%
graph=StateGraph(QuadraticState)

graph.add_node('show_equation', show_equation)
graph.add_node('calculate_discriminant', calculate_discriminant)
graph.add_node('real_roots', real_roots)
graph.add_node('repeated_roots', repeated_roots)
graph.add_node('no_real_roots', no_real_roots)

# %%
graph.add_edge(START, 'show_equation')
graph.add_edge('show_equation', 'calculate_discriminant')
graph.add_conditional_edges('calculate_discriminant', check_condition)
graph.add_edge('real_roots', END)
graph.add_edge('repeated_roots', END)
graph.add_edge('no_real_roots', END)

# %%
workflow=graph.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 workflow=graph.compile()
#
# File e:\LangGraph\myenv\Lib\site-packages\langgraph\graph\state.py:1113, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name)
#    1110 interrupt_after = interrupt_after or []
#    1112 # validate the graph
# -> 1113 self.validate(
#    1114     interrupt=(
#    1115         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1116         if interrupt_after != "*"
#    1117         else []
#    1118     )
#    1119 )
#    1121 # prepare output channels
#    1122 output_channels = (
#    1123     "__root__"
#    1124     if len(self.schemas[self.output_schema]) == 1
#    (...)   1130     ]
#    1131 )
#
# File e:\LangGraph\myenv\Lib\site-packages\langgraph\graph\state.py:1028, in StateGraph.validate(self, interrupt)
#    1026 for target in all_targets:
#    1027     if target not in self.nodes and target != END:
# -> 1028         raise ValueError(f"Found edge ending at unknown node `{target}`")
#    1029 # validate interrupts
#    1030 if interrupt:
#
# ValueError: Found edge ending at unknown node `<function check_condition at 0x0000027A86C7CCC0>`
